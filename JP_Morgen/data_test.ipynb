# %%
import os
os.chdir('/Users/yigewang/Desktop/Quant_AI/JP_Morgen')

# %%
import pandas as pd

# 选一个在 v3_data 里有 CSV 但没被加载的股票
df_test = pd.read_csv(f'./v3_data/BAC.csv', nrows=3)
print(f"Columns: {list(df_test.columns)}")
print(f"Shape: {df_test.shape}")
print(df_test)
